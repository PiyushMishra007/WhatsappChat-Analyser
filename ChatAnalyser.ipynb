# %%
import re
import pandas as pd

# %%
f=open("WhatsApp Chat with IT Section 2 Chat.txt","r",encoding="utf-8")
data=f.read()

# %%
#18/04/22, 12:22 am - Shivam Prasad Yadav: Sasta whatsapp
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s[ap]{1}m\s-\s'

# %%
message=re.split(pattern,data)[1:]
message
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'UAV: https://meetingsapac41.webex.com/meet/pr1664858481\n',
#  "+91 76968 56804: Hey folks 👐\n\nProgramming Club UIET is excited to bring our first session on 'Introduction to Python'. This session is for all the beginner level people who want to learn python or want to start programming.\n\nDate: 11 December 2020\nTime: 4 pm\nLink: https://meet.google.com/jnc-nhnq-qgk\n",
#  '+91 95963 81714: 😂😂\n',
#  '+91 89302 20242: <Media omitted>\n',
#  '+91 76968 56804: Anil Maurya Uiet office.vcf (file attached)\n',
#  'Nitin Kumar: https://classroom.google.com/c/MjM2OTg2NjY2MjE3?cjc=iatbwbi\n\nIT 2, Group 1 students only.\n\nPlease join Smithy Workshop.\n',
#  'Tanmay: <Media omitted>\n',
#  'UAV: <Media omitted>\n',
# ...

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['09/12/20, 12:49 pm - ',
#  '10/12/20, 11:43 am - ',
#  '11/12/20, 4:02 pm - ',
#  '12/12/20, 11:42 pm - ',
#  '14/12/20, 5:21 pm - ',
#  '16/12/20, 10:07 am - ',
#  '17/12/20, 11:42 pm - ',
#  '19/12/20, 11:34 am - ',
#  '24/12/20, 6:18 am - ',
#  '01/01/21, 1:10 pm - ',
#  '09/01/21, 11:18 am - ',
#  '15/01/21, 10:37 am - ',
#  '16/01/21, 12:03 pm - ',
#  '18/01/21, 4:40 pm - ',
#  '18/01/21, 10:06 pm - ',
#  '21/01/21, 9:31 pm - ',
#  '21/01/21, 9:31 pm - ',
#  '21/01/21, 9:31 pm - ',
#  '21/01/21, 9:32 pm - ',
#  '21/01/21, 9:32 pm - ',
#  '21/01/21, 9:32 pm - ',
#  '21/01/21, 9:32 pm - ',
#  '21/01/21, 9:33 pm - ',
#  '21/01/21, 9:33 pm - ',
#  '21/01/21, 9:34 pm - ',
#  '24/01/21, 2:57 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
#  '24/01/21, 8:04 pm - ',
# ...

# %%
#converting 12 hrs to 24 hrs
#df['Time'] = pd.to_datetime(df['Time'], format='%I:%M:%S %p').dt.strftime('%H:%M:%S')
df = pd.DataFrame({'user_message': message, 'message_date': dates})
#df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %I:%M %p - ').dt.strftime('%d-%m-%Y %H:%M')
# df['message_date'] = pd.to_datetime(df['message_date'], format='%d-%m-%Y %H:%M')
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %I:%M %p - ')
df.rename(columns={'message_date': 'date'}, inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2020-12-09 12:49:00
# 1  UAV: https://meetingsapac41.webex.com/meet/pr1... 2020-12-10 11:43:00
# 2  +91 76968 56804: Hey folks 👐\n\nProgramming Cl... 2020-12-11 16:02:00
# 3                              +91 95963 81714: 😂😂\n 2020-12-12 23:42:00
# 4                 +91 89302 20242: <Media omitted>\n 2020-12-14 17:21:00

# %%
 # convert message_date type
    
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])
df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)            
df.head()
# Out:
#                  date                user  \
# 0 2020-12-09 12:49:00  group_notification
# 1 2020-12-10 11:43:00                 UAV
# 2 2020-12-11 16:02:00     +91 76968 56804
# 3 2020-12-12 23:42:00     +91 95963 81714
# 4 2020-12-14 17:21:00     +91 89302 20242
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1  https://meetingsapac41.webex.com/meet/pr166485...
# 2   Hey folks 👐\n\nProgramming Club UIET is excit...
# 3                                               😂😂\n
# 4                                  <Media omitted>\n

# %%
df.dtypes
# Out:
# date       datetime64[ns]
# user               object
# message            object
# dtype: object

# %%
df['only_date'] = df['date'].dt.date
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute
df
# Out:
#                      date                user  \
# 0     2020-12-09 12:49:00  group_notification
# 1     2020-12-10 11:43:00                 UAV
# 2     2020-12-11 16:02:00     +91 76968 56804
# 3     2020-12-12 23:42:00     +91 95963 81714
# 4     2020-12-14 17:21:00     +91 89302 20242
# ...                   ...                 ...
# 20845 2023-01-15 15:12:00          Naman UIET
# 20846 2023-01-15 17:43:00            Medha CR
# 20847 2023-01-15 18:32:00  group_notification
# 20848 2023-01-15 22:00:00         Tanish UIET
# 20849 2023-01-15 22:00:00         Tanish UIET
#
#                                                  message   only_date  year  \
# 0      Messages and calls are end-to-end encrypted. N...  2020-12-09  2020
# 1      https://meetingsapac41.webex.com/meet/pr166485...  2020-12-10  2020
# 2       Hey folks 👐\n\nProgramming Club UIET is excit...  2020-12-11  2020
# 3                                                   😂😂\n  2020-12-12  2020
# ...

# %%
df[df['user']=='Medha CR'].shape
# Out:
# (627, 11)

# %%
words=[]
for message in df["message"]:
    words.extend(message.split())
print(len(words))
words
# Out:
# 97763
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'https://meetingsapac41.webex.com/meet/pr1664858481',
#  'Hey',
#  'folks',
#  '👐',
#  'Programming',
#  'Club',
#  'UIET',
#  'is',
#  'excited',
#  'to',
#  'bring',
#  'our',
#  'first',
#  'session',
#  'on',
#  "'Introduction",
#  'to',
#  "Python'.",
#  'This',
#  'session',
#  'is',
#  'for',
#  'all',
#  'the',
#  'beginner',
#  'level',
#  'people',
#  'who',
#  'want',
#  'to',
#  'learn',
#  'python',
#  'or',
#  'want',
#  'to',
#  'start',
#  'programming.',
#  'Date',
#  '11',
#  'December',
#  '2020',
#  'Time',
#  '4',
#  'pm',
#  'Link',
#  'https://meet.google.com/jnc-nhnq-qgk',
#  '😂😂',
#  '<Media',
#  'omitted>',
#  'Anil',
#  'Maurya',
#  'Uiet',
#  'office.vcf',
# ...

# %%
x=df["user"].value_counts().head()
new_df = round((df['user'].value_counts() / df.shape[0]) * 100, 2).reset_index().rename(columns={'index': 'name', 'user': 'percent'})

# %%
df
# Out:
#                      date                user  \
# 0     2020-12-09 12:49:00  group_notification
# 1     2020-12-10 11:43:00                 UAV
# 2     2020-12-11 16:02:00     +91 76968 56804
# 3     2020-12-12 23:42:00     +91 95963 81714
# 4     2020-12-14 17:21:00     +91 89302 20242
# ...                   ...                 ...
# 20845 2023-01-15 15:12:00          Naman UIET
# 20846 2023-01-15 17:43:00            Medha CR
# 20847 2023-01-15 18:32:00  group_notification
# 20848 2023-01-15 22:00:00         Tanish UIET
# 20849 2023-01-15 22:00:00         Tanish UIET
#
#                                                  message   only_date  year  \
# 0      Messages and calls are end-to-end encrypted. N...  2020-12-09  2020
# 1      https://meetingsapac41.webex.com/meet/pr166485...  2020-12-10  2020
# 2       Hey folks 👐\n\nProgramming Club UIET is excit...  2020-12-11  2020
# 3                                                   😂😂\n  2020-12-12  2020
# ...

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'https://meetingsapac41.webex.com/meet/pr1664858481',
#  'Hey',
#  'folks',
#  '👐',
#  'Programming',
#  'Club',
#  'UIET',
#  'is',
#  'excited',
#  'to',
#  'bring',
#  'our',
#  'first',
#  'session',
#  'on',
#  "'Introduction",
#  'to',
#  "Python'.",
#  'This',
#  'session',
#  'is',
#  'for',
#  'all',
#  'the',
#  'beginner',
#  'level',
#  'people',
#  'who',
#  'want',
#  'to',
#  'learn',
#  'python',
#  'or',
#  'want',
#  'to',
#  'start',
#  'programming.',
#  'Date',
#  '11',
#  'December',
#  '2020',
#  'Time',
#  '4',
#  'pm',
#  'Link',
#  'https://meet.google.com/jnc-nhnq-qgk',
#  '😂😂',
#  '<Media',
#  'omitted>',
#  'Anil',
#  'Maurya',
#  'Uiet',
#  'office.vcf',
#  '(file',
# ...

# %%
from collections import Counter
Counter(words).most_common(20)
# Out:
# [('<Media', 2635),
#  ('omitted>', 2635),
#  ('hai', 1402),
#  ('to', 1281),
#  ('h', 1172),
#  ('hi', 902),
#  ('bhi', 879),
#  ('ka', 782),
#  ('ki', 722),
#  ('Happy', 674),
#  ('se', 663),
#  ('ke', 654),
#  ('nhi', 640),
#  ('me', 596),
#  ('?', 553),
#  ('🙂', 548),
#  ('toh', 534),
#  ('kya', 516),
#  ('ko', 488),
#  ('the', 473)]

# %%
pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0     1
# 0     <Media  2635
# 1   omitted>  2635
# 2        hai  1402
# 3         to  1281
# 4          h  1172
# 5         hi   902
# 6        bhi   879
# 7         ka   782
# 8         ki   722
# 9      Happy   674
# 10        se   663
# 11        ke   654
# 12       nhi   640
# 13        me   596
# 14         ?   553
# 15         🙂   548
# 16       toh   534
# 17       kya   516
# 18        ko   488
# 19       the   473

# %%
#we need to remove stop words,message ommitted,group notification

# %%
temp=df[df['user']=='group_notification']
temp
# Out:
#                      date                user  \
# 0     2020-12-09 12:49:00  group_notification
# 470   2022-04-17 09:26:00  group_notification
# 586   2022-04-18 00:20:00  group_notification
# 587   2022-04-18 00:21:00  group_notification
# 595   2022-04-18 00:22:00  group_notification
# ...                   ...                 ...
# 19712 2022-12-12 00:05:00  group_notification
# 20193 2022-12-14 23:27:00  group_notification
# 20267 2022-12-15 07:47:00  group_notification
# 20423 2023-01-07 10:49:00  group_notification
# 20847 2023-01-15 18:32:00  group_notification
#
#                                                  message   only_date  year  \
# 0      Messages and calls are end-to-end encrypted. N...  2020-12-09  2020
# 470    Nitin Kumar changed the subject from "IT Secti...  2022-04-17  2022
# 586    Shivam Prasad Yadav changed the subject from "...  2022-04-18  2022
# 587    Shivam Prasad Yadav changed the subject from "...  2022-04-18  2022
# ...

# %%
temp=df[df['user']!='group_notification']
temp
# Out:
#                      date             user  \
# 1     2020-12-10 11:43:00              UAV
# 2     2020-12-11 16:02:00  +91 76968 56804
# 3     2020-12-12 23:42:00  +91 95963 81714
# 4     2020-12-14 17:21:00  +91 89302 20242
# 5     2020-12-16 10:07:00  +91 76968 56804
# ...                   ...              ...
# 20844 2023-01-15 14:58:00       Naman UIET
# 20845 2023-01-15 15:12:00       Naman UIET
# 20846 2023-01-15 17:43:00         Medha CR
# 20848 2023-01-15 22:00:00      Tanish UIET
# 20849 2023-01-15 22:00:00      Tanish UIET
#
#                                                  message   only_date  year  \
# 1      https://meetingsapac41.webex.com/meet/pr166485...  2020-12-10  2020
# 2       Hey folks 👐\n\nProgramming Club UIET is excit...  2020-12-11  2020
# 3                                                   😂😂\n  2020-12-12  2020
# 4                                      <Media omitted>\n  2020-12-14  2020
# ...

# %%
temp=temp[temp['message']!='<Media omitted>\n']
temp
# Out:
#                      date             user  \
# 1     2020-12-10 11:43:00              UAV
# 2     2020-12-11 16:02:00  +91 76968 56804
# 3     2020-12-12 23:42:00  +91 95963 81714
# 5     2020-12-16 10:07:00  +91 76968 56804
# 6     2020-12-17 23:42:00      Nitin Kumar
# ...                   ...              ...
# 20842 2023-01-13 22:27:00          Prakhar
# 20843 2023-01-13 22:28:00            Ankit
# 20846 2023-01-15 17:43:00         Medha CR
# 20848 2023-01-15 22:00:00      Tanish UIET
# 20849 2023-01-15 22:00:00      Tanish UIET
#
#                                                  message   only_date  year  \
# 1      https://meetingsapac41.webex.com/meet/pr166485...  2020-12-10  2020
# 2       Hey folks 👐\n\nProgramming Club UIET is excit...  2020-12-11  2020
# 3                                                   😂😂\n  2020-12-12  2020
# 5          Anil Maurya Uiet office.vcf (file attached)\n  2020-12-16  2020
# ...

# %%
temp['message']
# Out:
# 1        https://meetingsapac41.webex.com/meet/pr166485...
# 2         Hey folks 👐\n\nProgramming Club UIET is excit...
# 3                                                     😂😂\n
# 5            Anil Maurya Uiet office.vcf (file attached)\n
# 6        https://classroom.google.com/c/MjM2OTg2NjY2MjE...
#                                ...
# 20842                   🙂\nHypocrisy ki bhi seema hoti h\n
# 20843                                     Drive pe mili🫠\n
# 20846     Follow this link to join my WhatsApp group ht...
# 20848                        Kl ka lecture hoga na subha\n
# 20849                                        10 bje wala\n
# Name: message, Length: 18124, dtype: object

# %%
f = open('stop_hinglish.txt','r')
stop_words = f.read()
words=[]
for messages in temp['message']:
    for w in messages.lower().split():
            if w not in stop_words:
                words.append(w)

words
# Out:
# ['https://meetingsapac41.webex.com/meet/pr1664858481',
#  'folks',
#  '👐',
#  'programming',
#  'club',
#  'uiet',
#  'excited',
#  'bring',
#  'session',
#  "'introduction",
#  "python'.",
#  'session',
#  'beginner',
#  'level',
#  'learn',
#  'python',
#  'start',
#  'programming.',
#  'date',
#  '11',
#  'december',
#  '2020',
#  'pm',
#  'link',
#  'https://meet.google.com/jnc-nhnq-qgk',
#  '😂😂',
#  'anil',
#  'maurya',
#  'uiet',
#  'office.vcf',
#  '(file',
#  'attached)',
#  'https://classroom.google.com/c/mjm2otg2njy2mje3?cjc=iatbwbi',
#  '2,',
#  'group',
#  'students',
#  'only.',
#  'join',
#  'smithy',
#  'workshop.',
#  '🤠hola',
#  'folks!🤘🏻',
#  'feeling',
#  'shut',
#  'invigorating',
#  'activities?',
#  'here’s',
#  '*psych',
#  'club',
#  'uiet*',
#  'service👩🏼\u200d💼.',
#  'stimulate',
#  'mental',
#  'energy.',
#  'minds',
#  'shake',
#  'thoughts',
#  'expression',
#  'join',
#  'debate',
#  '“',
#  '*_quarantine',
#  'helped',
#  'not_*',
#  '”.',
#  '🤔🤔⁉️',
# ...

# %%
pd.DataFrame(Counter(words).most_common(20))
# Out:
#                 0    1
# 0           happy  711
# 1        birthday  614
# 2               🙂  548
# 3           class  372
# 4               😂  308
# 5             mam  193
# 6              😂😂  172
# 7               🤣  167
# 8             lab  161
# 9              🤣🤣  133
# 10  @919855927821  131
# 11          minor  128
# 12             cn  125
# 13          nahii  114
# 14            gya  113
# 15           baat  110
# 16            daa  110
# 17            pta  104
# 18            fer  103
# 19              🥲  101

# %%
import emoji
emojis=[]
for message in temp['message']:
    emojis.extend([c for c in message if c in emoji.UNICODE_EMOJI['en']])    
e = pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
e
# Out:
#      0     1
# 0    😂  1154
# 1    🙂  1030
# 2    🤣  1016
# 3    🔥   555
# 4    🎉   432
# ..  ..   ...
# 295  👽     1
# 296  🚅     1
# 297  ☯     1
# 298  🤨     1
# 299  🦥     1
#
# [300 rows x 2 columns]

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-12-09 12:49:00  group_notification
# 1 2020-12-10 11:43:00                 UAV
# 2 2020-12-11 16:02:00     +91 76968 56804
# 3 2020-12-12 23:42:00     +91 95963 81714
# 4 2020-12-14 17:21:00     +91 89302 20242
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-12-09  2020
# 1  https://meetingsapac41.webex.com/meet/pr166485...  2020-12-10  2020
# 2   Hey folks 👐\n\nProgramming Club UIET is excit...  2020-12-11  2020
# 3                                               😂😂\n  2020-12-12  2020
# 4                                  <Media omitted>\n  2020-12-14  2020
#
#    month_num     month  day   day_name  hour  minute
# 0         12  December    9  Wednesday    12      49
# 1         12  December   10   Thursday    11      43
# 2         12  December   11     Friday    16       2
# 3         12  December   12   Saturday    23      42
# ...

# %%
#df.groupby(['year','month_num','month','user','message']).first()
timeline=df.groupby(['year','month_num','month']).count()['message'].reset_index()
timeline
# Out:
#     year  month_num      month  message
# 0   2020         12   December        9
# 1   2021          1    January       44
# 2   2021          2   February       10
# 3   2021          3      March       24
# 4   2021          4      April       15
# 5   2021          5        May       10
# 6   2021          6       June        6
# 7   2021          7       July       11
# 8   2021          8     August       11
# 9   2021          9  September       21
# 10  2021         10    October        6
# 11  2021         11   November       13
# 12  2021         12   December        5
# 13  2022          1    January        8
# 14  2022          2   February        7
# 15  2022          3      March        6
# 16  2022          4      April     1664
# 17  2022          5        May     2818
# 18  2022          6       June     4583
# 19  2022          7       July      932
# 20  2022          8     August     1459
# 21  2022          9  September     1595
# ...

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i]+"-"+str(timeline['year'][i]))
time
# Out:
# ['December-2020',
#  'January-2021',
#  'February-2021',
#  'March-2021',
#  'April-2021',
#  'May-2021',
#  'June-2021',
#  'July-2021',
#  'August-2021',
#  'September-2021',
#  'October-2021',
#  'November-2021',
#  'December-2021',
#  'January-2022',
#  'February-2022',
#  'March-2022',
#  'April-2022',
#  'May-2022',
#  'June-2022',
#  'July-2022',
#  'August-2022',
#  'September-2022',
#  'October-2022',
#  'November-2022',
#  'December-2022',
#  'January-2023']

# %%
timeline['time']=time

# %%
timeline
# Out:
#     year  month_num      month  message            time
# 0   2020         12   December        9   December-2020
# 1   2021          1    January       44    January-2021
# 2   2021          2   February       10   February-2021
# 3   2021          3      March       24      March-2021
# 4   2021          4      April       15      April-2021
# 5   2021          5        May       10        May-2021
# 6   2021          6       June        6       June-2021
# 7   2021          7       July       11       July-2021
# 8   2021          8     August       11     August-2021
# 9   2021          9  September       21  September-2021
# 10  2021         10    October        6    October-2021
# 11  2021         11   November       13   November-2021
# 12  2021         12   December        5   December-2021
# 13  2022          1    January        8    January-2022
# 14  2022          2   February        7   February-2022
# 15  2022          3      March        6      March-2022
# ...

# %%
df1 = df[df['user'] == 'Piyush Mishra']
df1
# Out:
#                      date           user  \
# 337   2022-04-15 15:39:00  Piyush Mishra
# 475   2022-04-17 09:32:00  Piyush Mishra
# 678   2022-04-19 15:07:00  Piyush Mishra
# 679   2022-04-19 15:07:00  Piyush Mishra
# 680   2022-04-19 15:07:00  Piyush Mishra
# 682   2022-04-19 15:08:00  Piyush Mishra
# 2270  2022-05-03 08:52:00  Piyush Mishra
# 2801  2022-05-09 08:25:00  Piyush Mishra
# 2912  2022-05-11 08:33:00  Piyush Mishra
# 2926  2022-05-11 08:34:00  Piyush Mishra
# 2930  2022-05-11 08:35:00  Piyush Mishra
# 2933  2022-05-11 08:36:00  Piyush Mishra
# 2935  2022-05-11 08:39:00  Piyush Mishra
# 2936  2022-05-11 08:39:00  Piyush Mishra
# 2938  2022-05-11 08:40:00  Piyush Mishra
# 3337  2022-05-16 13:20:00  Piyush Mishra
# 3962  2022-05-24 14:52:00  Piyush Mishra
# 4450  2022-05-30 11:05:00  Piyush Mishra
# 5058  2022-06-03 16:43:00  Piyush Mishra
# 5059  2022-06-03 16:43:00  Piyush Mishra
# 5738  2022-06-07 10:23:00  Piyush Mishra
# 5753  2022-06-07 10:49:00  Piyush Mishra
# ...

# %%
 daily_timeline = df.groupby('only_date').count()['message'].reset_index()

# %%
daily_timeline
# Out:
#       only_date  message
# 0    2020-12-09        1
# 1    2020-12-10        1
# 2    2020-12-11        1
# 3    2020-12-12        1
# 4    2020-12-14        1
# ..          ...      ...
# 355  2023-01-10       74
# 356  2023-01-11       10
# 357  2023-01-12        2
# 358  2023-01-13       35
# 359  2023-01-15        6
#
# [360 rows x 2 columns]
